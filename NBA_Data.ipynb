# %%
# !pip install nba_api

# %%
import numpy as np
import pandas as pd

# %%
from nba_api.stats.endpoints import playercareerstats

# Player Stats by ID
career = playercareerstats.PlayerCareerStats(player_id='203932') 

# pandas data frames 
career.get_data_frames()[0]

# # json
# career.get_json()

# # dictionary
# career.get_dict()
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203932   2014-15        00  1610612753               ORL        19.0
# 1      203932   2015-16        00  1610612753               ORL        20.0
# 2      203932   2016-17        00  1610612753               ORL        21.0
# 3      203932   2017-18        00  1610612753               ORL        22.0
# 4      203932   2018-19        00  1610612753               ORL        23.0
# 5      203932   2019-20        00  1610612753               ORL        24.0
# 6      203932   2020-21        00  1610612753               ORL        25.0
# 7      203932   2020-21        00  1610612743               DEN        25.0
# 8      203932   2020-21        00           0               TOT        25.0
# 9      203932   2021-22        00  1610612743               DEN        26.0
# 10     203932   2022-23        00  1610612743               DEN        27.0
# ...

# %%
path = '/Users/torianotriche/Desktop/CourseraDataScience/NBAStatsPrac/NBA_Player_IDs.csv'
player_id = pd.read_csv(path)

# %%
player_id.head()
# Out:
#       BBRefName                                          BBRefLink    BBRefID  \
# 0  A.J. Hammons  https://www.basketball-reference.com/players/h...  hammoaj01
# 1    A.J. Price  https://www.basketball-reference.com/players/p...  priceaj01
# 2  Aaron Brooks  https://www.basketball-reference.com/players/b...  brookaa01
# 3  Aaron Gordon  https://www.basketball-reference.com/players/g...  gordoaa01
# 4    Aaron Gray  https://www.basketball-reference.com/players/g...   grayaa01
#
#   BBRefBirthDate       NBAName                                NBALink  \
# 0        8/27/92    AJ Hammons  https://stats.nba.com/player/1627773/
# 1        10/7/86      AJ Price   https://stats.nba.com/player/201985/
# 2        1/14/85  Aaron Brooks   https://stats.nba.com/player/201166/
# 3        9/16/95  Aaron Gordon   https://stats.nba.com/player/203932/
# 4        12/7/84    Aaron Gray   https://stats.nba.com/player/201189/
#
#        NBAID NBABirthDate      ESPNName  \
# ...

# %%
player_id.columns
# Out:
# Index(['BBRefName', 'BBRefLink', 'BBRefID', 'BBRefBirthDate', 'NBAName',
#        'NBALink', 'NBAID', 'NBABirthDate', 'ESPNName', 'ESPNLink', 'ESPNID',
#        'ESPNBirthDate', 'SpotracName', 'SpotracLink', 'SpotracID'],
#       dtype='object')

# %%
player_id = player_id[['NBAName',
       'NBALink', 'NBAID', 'NBABirthDate']]

# %%
player_id.tail()
# Out:
#      NBAName NBALink  NBAID NBABirthDate
# 4608     NaN     NaN    NaN          NaN
# 4609     NaN     NaN    NaN          NaN
# 4610     NaN     NaN    NaN          NaN
# 4611     NaN     NaN    NaN          NaN
# 4612     NaN     NaN    NaN          NaN

# %%
player_id.dropna(axis=0, inplace=True)

# %%
player_id.tail()
# Out:
#                 NBAName                                NBALink      NBAID  \
# 4524      Terrico White   https://stats.nba.com/player/202358/   202358.0
# 4525  Lindell Wigginton  https://stats.nba.com/player/1629623/  1629623.0
# 4526      Ward Williams    https://stats.nba.com/player/78573/    78573.0
# 4527        Hank Zeller    https://stats.nba.com/player/78642/    78642.0
# 4528         Matt Zunic    https://stats.nba.com/player/78650/    78650.0
#
#      NBABirthDate
# 4524       3/7/90
# 4525      3/28/98
# 4526      6/26/23
# 4527      7/10/18
# 4528     12/19/19

# %%
player_id.reset_index(drop=True, inplace=True)

# %%
player_id.tail()
# Out:
#                 NBAName                                NBALink      NBAID  \
# 4518      Terrico White   https://stats.nba.com/player/202358/   202358.0
# 4519  Lindell Wigginton  https://stats.nba.com/player/1629623/  1629623.0
# 4520      Ward Williams    https://stats.nba.com/player/78573/    78573.0
# 4521        Hank Zeller    https://stats.nba.com/player/78642/    78642.0
# 4522         Matt Zunic    https://stats.nba.com/player/78650/    78650.0
#
#      NBABirthDate
# 4518       3/7/90
# 4519      3/28/98
# 4520      6/26/23
# 4521      7/10/18
# 4522     12/19/19

# %%
LBJ = player_id[player_id['NBAName'] == 'LeBron James']['NBAID']
print(LBJ)
# Out:
# 610    2544.0
# Name: NBAID, dtype: float64

# %%
player_id['NBAID'] = player_id['NBAID'].astype(int)

# %%
player_id.head()
# Out:
#         NBAName                                NBALink    NBAID NBABirthDate
# 0    AJ Hammons  https://stats.nba.com/player/1627773/  1627773      8/27/92
# 1      AJ Price   https://stats.nba.com/player/201985/   201985      10/7/86
# 2  Aaron Brooks   https://stats.nba.com/player/201166/   201166      1/14/85
# 3  Aaron Gordon   https://stats.nba.com/player/203932/   203932      9/16/95
# 4    Aaron Gray   https://stats.nba.com/player/201189/   201189      12/7/84

# %%
path = '/Users/torianotriche/Desktop/CourseraDataScience/NBAStatsPrac/Nba_Player_Salaries.csv'
playerSalaries = pd.read_csv(path)

# %%
playerSalaries
# Out:
#      Player Id        Player Name     2022/2023     2023/2024     2024/2025  \
# 0            1      Stephen Curry  $48,070,014   $51,915,615   $55,761,217
# 1            2          John Wall  $47,345,760            $0            $0
# 2            3  Russell Westbrook  $47,080,179            $0            $0
# 3            4       LeBron James  $44,474,988   $46,698,737   $50,434,636
# 4            5       Kevin Durant  $44,119,845   $47,649,433   $51,179,020
# ..         ...                ...           ...           ...           ...
# 569        570          Gabe York      $32,171            $0            $0
# 570        571         Ibou Badji      $18,226    $1,761,752            $0
# 571        572   Tristan Thompson      $16,700            $0            $0
# 572        573       RaiQuan Gray       $5,849      $547,349            $0
# 573        573      Jacob Gilyard       $5,849      $547,349            $0
#
#       2024/2025.1
# 0    $59,606,817
# 1             $0
# ...

# %%
path = '/Users/torianotriche/Desktop/CourseraDataScience/NBAStatsPrac/NBA_Full_Salaries_2000-2019.csv'
playerSalaries2019 = pd.read_csv(path)

# %%
playerSalaries2019.head()
# Out:
#    Unnamed: 0              Name  Year    Salaries  Rank
# 0           1  Shaquille O'Neal  2000  17142000.0     1
# 1           2     Kevin Garnett  2000  16806000.0     2
# 2           3   Alonzo Mourning  2000  15004000.0     3
# 3           4      Juwan Howard  2000  15000000.0     4
# 4           5    Scottie Pippen  2000  14795000.0     5

# %%
playerSalaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Id    574 non-null    int64
#  1   Player Name  574 non-null    object
#  2   2022/2023    574 non-null    object
#  3   2023/2024    574 non-null    object
#  4   2024/2025    574 non-null    object
#  5   2024/2025.1  574 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 27.0+ KB

# %%
playerSalaries.columns
# Out:
# Index(['Player Id', 'Player Name', '2022/2023', '2023/2024', '2024/2025',
#        '2024/2025.1'],
#       dtype='object')

# %%
playerSalaries.head()
# Out:
#    Player Id        Player Name     2022/2023     2023/2024     2024/2025  \
# 0          1      Stephen Curry  $48,070,014   $51,915,615   $55,761,217
# 1          2          John Wall  $47,345,760            $0            $0
# 2          3  Russell Westbrook  $47,080,179            $0            $0
# 3          4       LeBron James  $44,474,988   $46,698,737   $50,434,636
# 4          5       Kevin Durant  $44,119,845   $47,649,433   $51,179,020
#
#     2024/2025.1
# 0  $59,606,817
# 1           $0
# 2           $0
# 3           $0
# 4  $54,708,608

# %%
playerSalaries['2024/2025'][playerSalaries['Player Name'] == 'Stephen Curry']
# Out:
# 0    $55,761,217
# Name: 2024/2025, dtype: object

# %%
player_id[player_id['NBAName'] == 'Russell Westbrook']
# Out:
#                NBAName                               NBALink   NBAID  \
# 818  Russell Westbrook  https://stats.nba.com/player/201566/  201566
#
#     NBABirthDate
# 818     11/12/88

# %%
playerSalaries.rename(columns={'Player Name':'NBAName'}, inplace=True)

# %%
playerSalaries
# Out:
#      Player Id            NBAName     2022/2023     2023/2024     2024/2025  \
# 0            1      Stephen Curry  $48,070,014   $51,915,615   $55,761,217
# 1            2          John Wall  $47,345,760            $0            $0
# 2            3  Russell Westbrook  $47,080,179            $0            $0
# 3            4       LeBron James  $44,474,988   $46,698,737   $50,434,636
# 4            5       Kevin Durant  $44,119,845   $47,649,433   $51,179,020
# ..         ...                ...           ...           ...           ...
# 569        570          Gabe York      $32,171            $0            $0
# 570        571         Ibou Badji      $18,226    $1,761,752            $0
# 571        572   Tristan Thompson      $16,700            $0            $0
# 572        573       RaiQuan Gray       $5,849      $547,349            $0
# 573        573      Jacob Gilyard       $5,849      $547,349            $0
#
#       2024/2025.1
# 0    $59,606,817
# 1             $0
# ...

# %%
player_id
# Out:
#                 NBAName                                NBALink    NBAID  \
# 0            AJ Hammons  https://stats.nba.com/player/1627773/  1627773
# 1              AJ Price   https://stats.nba.com/player/201985/   201985
# 2          Aaron Brooks   https://stats.nba.com/player/201166/   201166
# 3          Aaron Gordon   https://stats.nba.com/player/203932/   203932
# 4            Aaron Gray   https://stats.nba.com/player/201189/   201189
# ...                 ...                                    ...      ...
# 4518      Terrico White   https://stats.nba.com/player/202358/   202358
# 4519  Lindell Wigginton  https://stats.nba.com/player/1629623/  1629623
# 4520      Ward Williams    https://stats.nba.com/player/78573/    78573
# 4521        Hank Zeller    https://stats.nba.com/player/78642/    78642
# 4522         Matt Zunic    https://stats.nba.com/player/78650/    78650
#
#      NBABirthDate
# 0         8/27/92
# 1         10/7/86
# 2         1/14/85
# 3         9/16/95
# ...

# %%
print (pd.merge(player_id, playerSalaries, on='NBAName'))
# Out:
#                    NBAName                                NBALink    NBAID  \
# 0             Aaron Gordon   https://stats.nba.com/player/203932/   203932
# 1            Aaron Holiday  https://stats.nba.com/player/1628988/  1628988
# 2               Al Horford   https://stats.nba.com/player/201143/   201143
# 3               Alec Burks   https://stats.nba.com/player/202692/   202692
# 4              Alex Caruso  https://stats.nba.com/player/1627936/  1627936
# ..                     ...                                    ...      ...
# 308           Johnny Davis    https://stats.nba.com/player/76526/    76526
# 309          Armoni Brooks  https://stats.nba.com/player/1629717/  1629717
# 310           Juwan Morgan  https://stats.nba.com/player/1629752/  1629752
# 311  Juan Toscano-Anderson  https://stats.nba.com/player/1629308/  1629308
# 312      Lindell Wigginton  https://stats.nba.com/player/1629623/  1629623
#
# ...

# %%
merged_df = pd.merge(player_id, playerSalaries, on='NBAName')

# %%
merged_df
# Out:
#                    NBAName                                NBALink    NBAID  \
# 0             Aaron Gordon   https://stats.nba.com/player/203932/   203932
# 1            Aaron Holiday  https://stats.nba.com/player/1628988/  1628988
# 2               Al Horford   https://stats.nba.com/player/201143/   201143
# 3               Alec Burks   https://stats.nba.com/player/202692/   202692
# 4              Alex Caruso  https://stats.nba.com/player/1627936/  1627936
# ..                     ...                                    ...      ...
# 308           Johnny Davis    https://stats.nba.com/player/76526/    76526
# 309          Armoni Brooks  https://stats.nba.com/player/1629717/  1629717
# 310           Juwan Morgan  https://stats.nba.com/player/1629752/  1629752
# 311  Juan Toscano-Anderson  https://stats.nba.com/player/1629308/  1629308
# 312      Lindell Wigginton  https://stats.nba.com/player/1629623/  1629623
#
# ...

# %%
merged_df.rename(columns={'Player Id':'Rank'}, inplace=True)

# %%
merged_df.head()
# Out:
#          NBAName                                NBALink    NBAID NBABirthDate  \
# 0   Aaron Gordon   https://stats.nba.com/player/203932/   203932      9/16/95
# 1  Aaron Holiday  https://stats.nba.com/player/1628988/  1628988      9/30/96
# 2     Al Horford   https://stats.nba.com/player/201143/   201143       6/3/86
# 3     Alec Burks   https://stats.nba.com/player/202692/   202692      7/20/91
# 4    Alex Caruso  https://stats.nba.com/player/1627936/  1627936      2/28/94
#
#    Rank     2022/2023     2023/2024     2024/2025   2024/2025.1
# 0    68  $19,690,909   $21,266,182   $22,841,455   $22,841,455
# 1   381   $1,968,175            $0            $0            $0
# 2    52  $26,500,000   $10,000,000    $9,500,000            $0
# 3   144  $10,012,800   $10,489,600            $0            $0
# 4   160   $9,030,000    $9,460,000    $9,890,000            $0

# %%
merged_df.columns
# Out:
# Index(['NBAName', 'NBALink', 'NBAID', 'NBABirthDate', 'Rank', '2022/2023',
#        '2023/2024', '2024/2025', '2024/2025.1'],
#       dtype='object')

# %%
playerSalaries2023_24 = merged_df[['NBAName', 'NBALink', 'NBAID', 'NBABirthDate', 'Rank', '2023/2024',]]

# %%
playerSalaries2023_24
# Out:
#                    NBAName                                NBALink    NBAID  \
# 0             Aaron Gordon   https://stats.nba.com/player/203932/   203932
# 1            Aaron Holiday  https://stats.nba.com/player/1628988/  1628988
# 2               Al Horford   https://stats.nba.com/player/201143/   201143
# 3               Alec Burks   https://stats.nba.com/player/202692/   202692
# 4              Alex Caruso  https://stats.nba.com/player/1627936/  1627936
# ..                     ...                                    ...      ...
# 308           Johnny Davis    https://stats.nba.com/player/76526/    76526
# 309          Armoni Brooks  https://stats.nba.com/player/1629717/  1629717
# 310           Juwan Morgan  https://stats.nba.com/player/1629752/  1629752
# 311  Juan Toscano-Anderson  https://stats.nba.com/player/1629308/  1629308
# 312      Lindell Wigginton  https://stats.nba.com/player/1629623/  1629623
#
#     NBABirthDate  Rank     2023/2024
# ...

# %%
playerSalaries2023_24.rename(columns={'2023/2024':'Salary'}, inplace=True)
# Out:
# /var/folders/1w/gby26f3n765d28gknb15r_kh0000gn/T/ipykernel_4762/609228337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playerSalaries2023_24.rename(columns={'2023/2024':'Salary'}, inplace=True)

# %%
playerSalaries2023_24.head()
# Out:
#          NBAName                                NBALink    NBAID NBABirthDate  \
# 0   Aaron Gordon   https://stats.nba.com/player/203932/   203932      9/16/95
# 1  Aaron Holiday  https://stats.nba.com/player/1628988/  1628988      9/30/96
# 2     Al Horford   https://stats.nba.com/player/201143/   201143       6/3/86
# 3     Alec Burks   https://stats.nba.com/player/202692/   202692      7/20/91
# 4    Alex Caruso  https://stats.nba.com/player/1627936/  1627936      2/28/94
#
#    Rank        Salary
# 0    68  $21,266,182
# 1   381           $0
# 2    52  $10,000,000
# 3   144  $10,489,600
# 4   160   $9,460,000

# %%
playerSalaries2023_24[playerSalaries2023_24['NBAName'] == 'Stephen Curry']
# Out:
#            NBAName                               NBALink   NBAID NBABirthDate  \
# 211  Stephen Curry  https://stats.nba.com/player/201939/  201939      3/14/88
#
#      Rank        Salary
# 211     1  $51,915,615

# %%
from nba_api.stats.endpoints import playercareerstats

# Player Stats by ID
career = playercareerstats.PlayerCareerStats(player_id='201939') 

# pandas data frames 
stats = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stats
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      201939   2009-10        00  1610612744               GSW        22.0
# 1      201939   2010-11        00  1610612744               GSW        23.0
# 2      201939   2011-12        00  1610612744               GSW        24.0
# 3      201939   2012-13        00  1610612744               GSW        25.0
# 4      201939   2013-14        00  1610612744               GSW        26.0
# 5      201939   2014-15        00  1610612744               GSW        27.0
# 6      201939   2015-16        00  1610612744               GSW        28.0
# 7      201939   2016-17        00  1610612744               GSW        29.0
# 8      201939   2017-18        00  1610612744               GSW        30.0
# 9      201939   2018-19        00  1610612744               GSW        31.0
# 10     201939   2019-20        00  1610612744               GSW        32.0
# ...

# %%
playerSalaries2023_24.head()
# Out:
#          NBAName                                NBALink    NBAID NBABirthDate  \
# 0   Aaron Gordon   https://stats.nba.com/player/203932/   203932      9/16/95
# 1  Aaron Holiday  https://stats.nba.com/player/1628988/  1628988      9/30/96
# 2     Al Horford   https://stats.nba.com/player/201143/   201143       6/3/86
# 3     Alec Burks   https://stats.nba.com/player/202692/   202692      7/20/91
# 4    Alex Caruso  https://stats.nba.com/player/1627936/  1627936      2/28/94
#
#    Rank        Salary
# 0    68  $21,266,182
# 1   381           $0
# 2    52  $10,000,000
# 3   144  $10,489,600
# 4   160   $9,460,000

# %%
path = 'https://nba-stats-db.herokuapp.com/api/playerdata/season/2023'
seasonStats = pd.read_json(path)

seasonStats1 = pd.json_normalize(seasonStats['results'])

# %%
seasonStats1
# Out:
#      id        player_name  age  games  games_started  minutes_played  \
# 0     1        Jalen Green   20     76             76            2602
# 1     2   Jabari Smith Jr.   19     79             79            2451
# 2     3  Kenyon Martin Jr.   22     82             49            2292
# 3     4     Alperen Şengün   20     75             72            2171
# 4     5   Kevin Porter Jr.   22     59             59            2024
# ..  ...                ...  ...    ...            ...             ...
# 95   96       Nerlens Noel   28      3              1              43
# 96   97       RaiQuan Gray   23      1              0              35
# 97   98        Moses Brown   23      2              0               6
# 98   99   Alondes Williams   23      1              0               5
# 99  100     Scottie Barnes   21     77             76            2678
#
#     field_goals  field_attempts field_percent  three_fg  three_attempts  \
# ...

# %%
stats = pd.json_normalize(seasonStats['results'])
df = pd.DataFrame(data=stats)
df
# Out:
#      id        player_name  age  games  games_started  minutes_played  \
# 0     1        Jalen Green   20     76             76            2602
# 1     2   Jabari Smith Jr.   19     79             79            2451
# 2     3  Kenyon Martin Jr.   22     82             49            2292
# 3     4     Alperen Şengün   20     75             72            2171
# 4     5   Kevin Porter Jr.   22     59             59            2024
# ..  ...                ...  ...    ...            ...             ...
# 95   96       Nerlens Noel   28      3              1              43
# 96   97       RaiQuan Gray   23      1              0              35
# 97   98        Moses Brown   23      2              0               6
# 98   99   Alondes Williams   23      1              0               5
# 99  100     Scottie Barnes   21     77             76            2678
#
#     field_goals  field_attempts field_percent  three_fg  three_attempts  \
# ...

# %%
from nba_api.stats.endpoints import scoreboard

# Player Stats by ID
career = scoreboard.Scoreboard(game_date='2023-01-13T00:00:00') 

# pandas data frames 
stat2 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat2
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2023-01-13T00:00:00              1  0022200632               3
# 1  2023-01-13T00:00:00              2  0022200633               3
# 2  2023-01-13T00:00:00              3  0022200634               3
# 3  2023-01-13T00:00:00              4  0022200635               3
# 4  2023-01-13T00:00:00              5  0022200636               3
# 5  2023-01-13T00:00:00              6  0022200637               3
# 6  2023-01-13T00:00:00              7  0022200638               3
# 7  2023-01-13T00:00:00              8  0022200639               3
# 8  2023-01-13T00:00:00              9  0022200640               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20230113/NOPDET    1610612765       1610612740   2022
# 1            Final  20230113/ATLIND    1610612754       1610612737   2022
# 2            Final  20230113/NYKWAS    1610612764       1610612752   2022
# ...

# %%
from nba_api.stats.endpoints import playbyplay

# Player Stats by ID
career = playbyplay.PlayByPlay(game_id='0022200639') 

# pandas data frames 
stat3 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat3
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0    0022200639         2            12                   0       1
# 1    0022200639         9            10                   0       1
# 2    0022200639         5             2                  79       1
# 3    0022200639         6             4                   0       1
# 4    0022200639         7             2                 101       1
# ..          ...       ...           ...                 ...     ...
# 408  0022200639       562             4                   0       4
# 409  0022200639       563             1                   1       4
# 410  0022200639       565             2                   6       4
# 411  0022200639       566             4                   0       4
# 412  0022200639       569            13                   0       4
#
#     WCTIMESTRING PCTIMESTRING                          HOMEDESCRIPTION  \
# 0       10:16 PM        12:00                                     None
# ...

# %%
stat3.columns
# Out:
# Index(['GAME_ID', 'EVENTNUM', 'EVENTMSGTYPE', 'EVENTMSGACTIONTYPE', 'PERIOD',
#        'WCTIMESTRING', 'PCTIMESTRING', 'HOMEDESCRIPTION', 'NEUTRALDESCRIPTION',
#        'VISITORDESCRIPTION', 'SCORE', 'SCOREMARGIN'],
#       dtype='object')

# %%
from nba_api.stats.endpoints import leaguestandingsv3

# Player Stats by ID
career = leaguestandingsv3.LeagueStandingsV3(season=2022) 

# pandas data frames 
stat4 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat4
# Out:
#    LeagueID SeasonID      TeamID       TeamCity       TeamName      TeamSlug  \
# 0        00    22022  1610612743         Denver        Nuggets       nuggets
# 1        00    22022  1610612749      Milwaukee          Bucks         bucks
# 2        00    22022  1610612738         Boston        Celtics       celtics
# 3        00    22022  1610612763        Memphis      Grizzlies     grizzlies
# 4        00    22022  1610612758     Sacramento          Kings         kings
# 5        00    22022  1610612755   Philadelphia          76ers        sixers
# 6        00    22022  1610612739      Cleveland      Cavaliers     cavaliers
# 7        00    22022  1610612756        Phoenix           Suns          suns
# 8        00    22022  1610612746             LA       Clippers      clippers
# 9        00    22022  1610612752       New York         Knicks        knicks
# 10       00    22022  1610612744   Golden State       Warriors      warriors
# ...

# %%
stat4.head()
# Out:
#   LeagueID SeasonID      TeamID    TeamCity   TeamName   TeamSlug Conference  \
# 0       00    22022  1610612743      Denver    Nuggets    nuggets       West
# 1       00    22022  1610612749   Milwaukee      Bucks      bucks       East
# 2       00    22022  1610612738      Boston    Celtics    celtics       East
# 3       00    22022  1610612763     Memphis  Grizzlies  grizzlies       West
# 4       00    22022  1610612758  Sacramento      Kings      kings       West
#
#   ConferenceRecord  PlayoffRank ClinchIndicator   Division DivisionRecord  \
# 0            34-18            1             - w  Northwest           10-6
# 1            35-17            1             - e    Central           11-5
# 2            34-18            2             - a   Atlantic           11-5
# 3            30-22            2            - sw  Southwest           13-3
# 4            32-20            3             - p    Pacific            9-7
#
# ...

# %%
stat4[stat4['Division'] == 'Atlantic']
# Out:
#    LeagueID SeasonID      TeamID      TeamCity TeamName TeamSlug Conference  \
# 2        00    22022  1610612738        Boston  Celtics  celtics       East
# 5        00    22022  1610612755  Philadelphia    76ers   sixers       East
# 9        00    22022  1610612752      New York   Knicks   knicks       East
# 11       00    22022  1610612751      Brooklyn     Nets     nets       East
# 17       00    22022  1610612761       Toronto  Raptors  raptors       East
#
#    ConferenceRecord  PlayoffRank ClinchIndicator  Division DivisionRecord  \
# 2             34-18            2             - a  Atlantic           11-5
# 5             34-18            3             - x  Atlantic           10-6
# 9             32-20            5             - x  Atlantic            8-8
# 11            30-22            6             - x  Atlantic            7-9
# 17            26-26            9            - pi  Atlantic           4-12
#
# ...

# %%
stat4.columns
# Out:
# Index(['LeagueID', 'SeasonID', 'TeamID', 'TeamCity', 'TeamName', 'TeamSlug',
#        'Conference', 'ConferenceRecord', 'PlayoffRank', 'ClinchIndicator',
#        'Division', 'DivisionRecord', 'DivisionRank', 'WINS', 'LOSSES',
#        'WinPCT', 'LeagueRank', 'Record', 'HOME', 'ROAD', 'L10', 'Last10Home',
#        'Last10Road', 'OT', 'ThreePTSOrLess', 'TenPTSOrMore', 'LongHomeStreak',
#        'strLongHomeStreak', 'LongRoadStreak', 'strLongRoadStreak',
#        'LongWinStreak', 'LongLossStreak', 'CurrentHomeStreak',
#        'strCurrentHomeStreak', 'CurrentRoadStreak', 'strCurrentRoadStreak',
#        'CurrentStreak', 'strCurrentStreak', 'ConferenceGamesBack',
#        'DivisionGamesBack', 'ClinchedConferenceTitle', 'ClinchedDivisionTitle',
#        'ClinchedPlayoffBirth', 'ClinchedPlayIn', 'EliminatedConference',
#        'EliminatedDivision', 'AheadAtHalf', 'BehindAtHalf', 'TiedAtHalf',
#        'AheadAtThird', 'BehindAtThird', 'TiedAtThird', 'Score100PTS',
# ...

# %%
from nba_api.stats.endpoints import leagueleaders

# Player Stats by ID
career = leagueleaders.LeagueLeaders(season='2022-23') 

# pandas data frames 
stat5 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat5.head(10)
# Out:
#    PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 0    1628369     1             Jayson Tatum  1610612738  BOS  74  2732  727
# 1     203954     2              Joel Embiid  1610612755  PHI  66  2284  728
# 2    1629029     3              Luka Doncic  1610612742  DAL  66  2391  719
# 3    1628983     4  Shai Gilgeous-Alexander  1610612760  OKC  68  2416  704
# 4     203507     5    Giannis Antetokounmpo  1610612749  MIL  63  2024  707
# 5    1630162     6          Anthony Edwards  1610612750  MIN  79  2841  707
# 6     203944     7            Julius Randle  1610612752  NYK  77  2737  658
# 7    1628378     8         Donovan Mitchell  1610612739  CLE  68  2432  679
# 8    1629027     9               Trae Young  1610612737  ATL  73  2541  597
# 9     203897    10              Zach LaVine  1610612741  CHI  77  2768  673
#
#     FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  \
# ...

# %%
stat5.head(10)
# Out:
#    PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 0    1628369     1             Jayson Tatum  1610612738  BOS  74  2732  727
# 1     203954     2              Joel Embiid  1610612755  PHI  66  2284  728
# 2    1629029     3              Luka Doncic  1610612742  DAL  66  2391  719
# 3    1628983     4  Shai Gilgeous-Alexander  1610612760  OKC  68  2416  704
# 4     203507     5    Giannis Antetokounmpo  1610612749  MIL  63  2024  707
# 5    1630162     6          Anthony Edwards  1610612750  MIN  79  2841  707
# 6     203944     7            Julius Randle  1610612752  NYK  77  2737  658
# 7    1628378     8         Donovan Mitchell  1610612739  CLE  68  2432  679
# 8    1629027     9               Trae Young  1610612737  ATL  73  2541  597
# 9     203897    10              Zach LaVine  1610612741  CHI  77  2768  673
#
#     FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  \
# ...

# %%
stat5[stat5['TEAM'] == 'CHI']
# Out:
#      PLAYER_ID  RANK             PLAYER     TEAM_ID TEAM  GP   MIN  FGM   FGA  \
# 9       203897    10        Zach LaVine  1610612741  CHI  77  2768  673  1388
# 12      201942    13      DeMar DeRozan  1610612741  CHI  74  2682  657  1303
# 36      202696    37     Nikola Vucevic  1610612741  CHI  82  2746  597  1148
# 119    1630172   119   Patrick Williams  1610612741  CHI  82  2323  314   677
# 145    1629632   146         Coby White  1610612741  CHI  74  1730  263   594
# 161    1630245   162        Ayo Dosunmu  1610612741  CHI  80  2098  281   570
# 256     201976   255   Patrick Beverley  1610612741  CHI  67  1817  144   360
# 259     203083   260     Andre Drummond  1610612741  CHI  67   849  166   274
# 269    1627936   270        Alex Caruso  1610612741  CHI  67  1575  130   286
# 290    1627884   291  Derrick Jones Jr.  1610612741  CHI  64   893  115   230
# 373    1629750   373      Javonte Green  1610612741  CHI  32   480   61   108
# ...

# %%
from nba_api.stats.endpoints import teamgamelog

# Player Stats by ID
career = teamgamelog.TeamGameLog(season=2022, team_id='1610612741') 

# pandas data frames 
stat6 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat6
# Out:
#        Team_ID     Game_ID     GAME_DATE      MATCHUP WL   W   L  W_PCT  MIN  \
# 0   1610612741  0022201223  APR 09, 2023  CHI vs. DET  W  40  42  0.488  240
# 1   1610612741  0022201210  APR 07, 2023    CHI @ DAL  W  39  42  0.481  240
# 2   1610612741  0022201193  APR 05, 2023    CHI @ MIL  L  38  42  0.475  240
# 3   1610612741  0022201182  APR 04, 2023  CHI vs. ATL  L  38  41  0.481  240
# 4   1610612741  0022201165  APR 02, 2023  CHI vs. MEM  W  38  40  0.487  240
# ..         ...         ...           ...          ... ..  ..  ..    ...  ...
# 77  1610612741  0022200061  OCT 26, 2022  CHI vs. IND  W   3   2  0.600  240
# 78  1610612741  0022200047  OCT 24, 2022  CHI vs. BOS  W   2   2  0.500  240
# 79  1610612741  0022200032  OCT 22, 2022  CHI vs. CLE  L   1   2  0.333  240
# 80  1610612741  0022200019  OCT 21, 2022    CHI @ WAS  L   1   1  0.500  240
# 81  1610612741  0022200007  OCT 19, 2022    CHI @ MIA  W   1   0  1.000  240
#
# ...

# %%
from nba_api.stats.endpoints import teamdetails

# Player Stats by ID
career = teamdetails.TeamDetails(team_id='1610612741') 

# pandas data frames 
stat7 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat7
# Out:
#       TEAM_ID ABBREVIATION NICKNAME  YEARFOUNDED     CITY          ARENA  \
# 0  1610612741          CHI    Bulls         1966  Chicago  United Center
#
#   ARENACAPACITY              OWNER      GENERALMANAGER      HEADCOACH  \
# 0         21711  Michael Reinsdorf  Arturas Karnisovas  Billy Donovan
#
#   DLEAGUEAFFILIATION
# 0   Windy City Bulls

# %%
from nba_api.stats.endpoints import shotchartdetail

# Player Stats by ID
career = shotchartdetail.ShotChartDetail(team_id='1610612741', player_id='201942') 

# pandas data frames 
stat8 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat8
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0    Shot Chart Detail  0022300004             13     201942  DeMar DeRozan
# 1    Shot Chart Detail  0022300004             34     201942  DeMar DeRozan
# 2    Shot Chart Detail  0022300004             47     201942  DeMar DeRozan
# 3    Shot Chart Detail  0022300004             50     201942  DeMar DeRozan
# 4    Shot Chart Detail  0022300004            262     201942  DeMar DeRozan
# ..                 ...         ...            ...        ...            ...
# 299  Shot Chart Detail  0022301223            453     201942  DeMar DeRozan
# 300  Shot Chart Detail  0022301223            550     201942  DeMar DeRozan
# 301  Shot Chart Detail  0022301223            620     201942  DeMar DeRozan
# 302  Shot Chart Detail  0022301223            674     201942  DeMar DeRozan
# 303  Shot Chart Detail  0022301223            680     201942  DeMar DeRozan
#
# ...

# %%
from nba_api.stats.endpoints import playerindex

# Player Stats by ID
career = playerindex.PlayerIndex() 

# pandas data frames 
stat9 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat9
# Out:
#      PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME       PLAYER_SLUG  \
# 0      1630173          Achiuwa          Precious  precious-achiuwa
# 1       203500            Adams            Steven      steven-adams
# 2      1628389          Adebayo               Bam       bam-adebayo
# 3      1630534           Agbaji             Ochai      ochai-agbaji
# 4      1630583           Aldama             Santi      santi-aldama
# ..         ...              ...               ...               ...
# 538     201152            Young          Thaddeus    thaddeus-young
# 539    1629027            Young              Trae        trae-young
# 540    1630209        Yurtseven              Omer    omer-yurtseven
# 541     203469           Zeller              Cody       cody-zeller
# 542    1627826            Zubac             Ivica       ivica-zubac
#
#         TEAM_ID  TEAM_SLUG  IS_DEFUNCT    TEAM_CITY  TEAM_NAME  \
# 0    1610612752     knicks           0     New York     Knicks
# ...

# %%
from nba_api.stats.endpoints import playerfantasyprofilebargraph

# Player Stats by ID
career = playerfantasyprofilebargraph.PlayerFantasyProfileBarGraph(player_id='201942', ) 

# pandas data frames 
stat10 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat10
# Out:
#    PLAYER_ID    PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  FAN_DUEL_PTS  \
# 0     201942  DeMar DeRozan  1610612741               CHI          37.1
#
#    NBA_FANTASY_PTS   PTS  REB  AST  FG3M  FT_PCT   STL   BLK  TOV  FG_PCT
# 0             38.8  22.4  3.9  5.3   1.0   0.849  1.08  0.67  1.4   0.466

# %%
from nba_api.stats.endpoints import playergamelog

# Player Stats by ID
career = playergamelog.PlayerGameLog(player_id='1628389') 

# pandas data frames 
stat11 = career.get_data_frames()[0]
pd.set_option('display.max_column', None)

# %%
stat11.head()
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22023    1628389  0022300551  JAN 14, 2024  MIA vs. CHA  W   35    9
# 1     22023    1628389  0022300535  JAN 12, 2024  MIA vs. ORL  W   39    8
# 2     22023    1628389  0022300522  JAN 10, 2024  MIA vs. OKC  L   37    9
# 3     22023    1628389  0022300509  JAN 08, 2024  MIA vs. HOU  W   32    9
# 4     22023    1628389  0022300489  JAN 05, 2024    MIA @ PHX  L   36   11
#
#    FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  \
# 0   17   0.529     0     1      0.0    6    8   0.750     0    10   10    7
# 1   17   0.471     0     0      0.0    5    6   0.833     4     7   11    7
# 2   16   0.563     0     0      0.0    7    7   1.000     5     6   11    6
# 3   12   0.750     0     0      0.0    4    7   0.571     1    11   12    3
# 4   19   0.579     0     0      0.0    6    7   0.857     2     8   10    1
#
#    STL  BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# ...

# %%
from nba_api.stats.static import players

# Player Stats by ID
career = players.get_active_players()

# pandas data frames 
stat22 = pd.json_normalize(career)
pd.set_option('display.max_column', None)

# %%
stat22.head()
# Out:
#         id         full_name first_name last_name  is_active
# 0  1630173  Precious Achiuwa   Precious   Achiuwa       True
# 1   203500      Steven Adams     Steven     Adams       True
# 2  1628389       Bam Adebayo        Bam   Adebayo       True
# 3  1630534      Ochai Agbaji      Ochai    Agbaji       True
# 4  1630583      Santi Aldama      Santi    Aldama       True

# %%
from nba_api.stats.static import teams

teamList = teams.get_teams()

stat33 = pd.json_normalize(teamList)
pd.set_option('display.max_column', None)

# %%
stat33.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
def get
